# %%
import numpy as np
from twaidata.MRI_preprep.io import load_nii_img, save_nii_img, FORMAT
import matplotlib.pyplot as plt

# %%
indir = "/media/benp/NVMEspare/datasets/preprocessing_attempts/local_results/WMH_challenge_dataset/Utrecht/imgs/"

# %%
FORMAT = ".nii.gz"
ind = 0
flair = f"{indir}{ind}_FLAIR{FORMAT}"
mask = f"{indir}{ind}_FLAIR_BET_mask{FORMAT}"
t1 = f"{indir}{ind}_T1{FORMAT}"

# %%
flair, _ = load_nii_img(flair)
mask, _ = load_nii_img(mask)
t1, _ = load_nii_img(t1)

# %%
flair.shape, mask.shape, t1.shape
# Out:
# ((230, 230, 48), (230, 230, 48), (230, 230, 48))

# %%
plt.imshow(flair[:,:,25])

# %%
plt.imshow(mask[:,:,25])

# %%
plt.imshow(t1[:,:,25])
